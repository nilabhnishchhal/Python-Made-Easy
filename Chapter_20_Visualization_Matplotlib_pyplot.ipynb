# %% [markdown]
# # Visualization using Matplotlib.pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
fig = plt.gcf()
fig.savefig('plot1.png', dpi=300)

# %%
fig

# %%
ax

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
fig = plt.gcf()
fig.savefig('plot3.png', dpi=300)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.
fig = plt.gcf()
fig.savefig('plot4.png', dpi=300)

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
fig = plt.gcf()
fig.savefig('plot5.png', dpi=300)

# %%
x = np.linspace(0, 2, 100)        # Creating numpy array as the data to plot for this example. 

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.

fig, ax = plt.subplots()                # Create a figure and an axes
ax.plot(x, x, label = "linear")          # Plot some data on the axes
ax.plot(x, x**2, label = "quardratic")   # Plot more data on the axes...
ax.plot(x, x**3, label = "cubic")        # and some more data...
ax.set_xlabel('x label')             # Add an x-label to the axes.
ax.set_ylabel('y label')             # Add a y-label to the axes.
ax.set_title("Simple Plot")          # Add a title to the axes.
ax.legend()                          # Add a legend.
fig = plt.gcf()
fig.savefig('plot6.png', dpi=300)

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label = "linear")          # Plot some data on the axes
plt.plot(x, x**2, label = "quardratic")   # Plot more data on the axes...
plt.plot(x, x**3, label = "cubic")        # and some more data...
plt.xlabel('x label')             # Add an x-label to the axes.
plt.ylabel('y label')             # Add a y-label to the axes.
plt.title("Simple Plot")          # Add a title to the axes.
plt.legend()                          # Add a legend.
fig = plt.gcf()
fig.savefig('plot7.png', dpi=300)

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
# %matplotlib inline

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})
fig = plt.gcf()
fig.savefig('plot8.png', dpi=300)

# %% [markdown]
# The same function can be used to draw sublots too. If you wanted to have 2 sub-plots:

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})
fig = plt.gcf()
fig.savefig('plot9.png', dpi=300)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
fig = plt.gcf()
fig.savefig('plot10.png', dpi=300)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
fig = plt.gcf()
fig.savefig('plot11.png', dpi=300)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
fig = plt.gcf()
fig.savefig('plot12.png', dpi=300)

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
fig = plt.gcf()
fig.savefig('plot13.png', dpi=300)

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
fig = plt.gcf()
fig.savefig('plot14.png', dpi=300)

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)                 # Subplot(1 row, 3 colums, 1st object)
plt.bar(names, values)
plt.subplot(132)                 # Subplot(1 row, 3 colums, 2nd object)
plt.scatter(names, values)
plt.subplot(133)                 # Subplot(1 row, 3 colums, 3rd object)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
fig = plt.gcf()
fig.savefig('plot15.png', dpi=300)

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
fig = plt.gcf()
fig.savefig('plot16.png', dpi=300)

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])

fig = plt.gcf()
fig.savefig('plot17.png', dpi=300)
plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
fig = plt.gcf()
fig.savefig('plot18.png', dpi=300)
# Out:
# C:\Users\nilabhnishchhal\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts', fontsize=14, color='red')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
fig = plt.gcf()
fig.savefig('plot19.png', dpi=300)

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
fig = plt.gcf()
fig.savefig('plot20.png', dpi=300)

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.99, bottom=0.05, left=0.10, right=0.99, hspace=0.50, wspace=0.65)

fig = plt.gcf()
fig.savefig('plot21.png', dpi=300)
